# %%
print('Welcome to Introduction to Computer course')
# Out:
# Welcome to Introduction to Computer course

# %%
lst = [15,13,10,2,1,9,100,50]
l = len(lst)

for n in range(l+1) :
  for m in range(l-n-1) :
    if lst[m+1] > lst[m] :
      lst[m], lst[m+1] = lst[m+1], lst[m]

print(lst)
# Out:
# [100, 50, 15, 13, 10, 9, 2, 1]
