# %%
print('Welcome to Introduction to Computer course')
# Out:
# Welcome to Introduction to Computer course

# %%
lst = [5, 6, 1, 8, 11, 3]

for i in range(0,len(lst)+1) :
  for j in range(0,n-i-1) :
    if lst[j] > lst[j+1] :
      lst[j], lst[j+1] = lst[j+1], lst[j]
print(lst)
# Out:
# [1, 3, 5, 6, 8, 11]

# %%
seq='...'
print(f'Length of sequence is {len(seq)}\n')

#Q4(a)
mono = set(seq)
print(f'Mononuleotides are {mono}\n')

#Q4(b)
monocounts = {}
for char in mono :
  count = 0
  for i in seq :
    if char == i :
      count += 1
  monocounts[char] = count
print(monocounts)

#Q4(c)
di = []
for char1 in mono :
  for char2 in mono :
    di.append(char1 + char2)
print(f'\n{di}\nThere are {len(di)} combinations.\n')

#Q4(d)
di = {}
for char in p :
  if char in seq :
    di[char] = seq.count(char)
print(f'Maximum occuring mononucleotide is: {max(monocounts)} - {max(monocounts.values())} times')
print(f'Maximum occuring dinucleotide is: {max(di)} - {max(di.values())} times')
# Out:
# Length of sequence is 915
#
# Mononuleotides are {'a', 'A', 'c', 'C', 't', 'G', 'g', 'T'}
#
# {'a': 34, 'A': 172, 'c': 47, 'C': 177, 't': 53, 'G': 212, 'g': 71, 'T': 149}
#
# ['aa', 'aA', 'ac', 'aC', 'at', 'aG', 'ag', 'aT', 'Aa', 'AA', 'Ac', 'AC', 'At', 'AG', 'Ag', 'AT', 'ca', 'cA', 'cc', 'cC', 'ct', 'cG', 'cg', 'cT', 'Ca', 'CA', 'Cc', 'CC', 'Ct', 'CG', 'Cg', 'CT', 'ta', 'tA', 'tc', 'tC', 'tt', 'tG', 'tg', 'tT', 'Ga', 'GA', 'Gc', 'GC', 'Gt', 'GG', 'Gg', 'GT', 'ga', 'gA', 'gc', 'gC', 'gt', 'gG', 'gg', 'gT', 'Ta', 'TA', 'Tc', 'TC', 'Tt', 'TG', 'Tg', 'TT']
# There are 64 combinations.
#
# Maximum occuring mononucleotide is: t - 212 times
# Maximum occuring dinucleotide is: tt - 67 times

# %%
#Q5-a
data = [['Adrian',55,65,90,88], ['Jasuz',75,64,95,96], ['Jeffrey',81,79,58,82], ['Michal',79,89,80,65], ['Piotr',85,81,78,80]]

for student in data :
  name = student[0]
  marks = student[1:]
  avg = sum(marks)/len(marks)
  print(f'{name}: avg = {avg}')

print()

#Q5-b
for n,subject in enumerate(['math', 'bio', 'chm', 'phy'], start=1) :
  marks = []
  for student in data :
    marks.append(student[n])
  avg = sum(marks)/len(marks)
  print(f'{subject}: avg = {avg}')

print()

#Q5-C
data = {'Adrian':{'math':55, 'bio':65, 'chem':90, 'phy':88},
        'Jasuz':{'math':75, 'bio':64, 'chem':95, 'phy':96},
        'Jeffrey':{'math':81, 'bio':79, 'chem':58, 'phy':82},
        'Michal':{'math':79, 'bio':89, 'chem':80, 'phy':65},
        'Piotr':{'math':85, 'bio':81, 'chem':78, 'phy':80}
        }

subjects = set()

for name,scores in data.items() :
  student_marks = []
  for subject,score in scores.items() :
    student_marks.append(score)
    subjects.add(subject)
  print(f'{name}: avg = {sum(student_marks)/len(student_marks)}')

print()

for subject in subjects :
  subject_marks = []
  for name,scores in data.items() :
    subject_marks.append(scores[subject])
  print(f'{subject}: avg = {sum(subject_marks)/len(subject_marks)}')
# Out:
# Adrian: avg = 74.5
# Jasuz: avg = 82.5
# Jeffrey: avg = 75.0
# Michal: avg = 78.25
# Piotr: avg = 81.0
#
# math: avg = 75.0
# bio: avg = 75.6
# chm: avg = 80.2
# phy: avg = 82.2
#
# Adrian: avg = 74.5
# Jasuz: avg = 82.5
# Jeffrey: avg = 75.0
# Michal: avg = 78.25
# Piotr: avg = 81.0
#
# chem: avg = 80.2
# bio: avg = 75.6
# phy: avg = 82.2
# math: avg = 75.0
